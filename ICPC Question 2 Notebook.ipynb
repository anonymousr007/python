# %% [markdown]
# # 2. Compute the popcount function for n(large number of inputs) qubits
# Compute the popcount function for n = 15 qubits.
# <h3>
# $$|x,0,0\rangle \mapsto e^{i\theta(x)}|x,\text{Popcount}(x),0\rangle$$

# %% [markdown]
# ## a) Circuit for n = 15 Popcount function

# %%
# Importing the qiskit module
from qiskit import *

# Defining input, output and scratch qubits
x15 =  15  # number of input qubits
y15 =  4  # number of output qubit 
s15 =  22  # number of scratch qubit

# Defining Quantum Circuit with the given circuits
def Circuit_15(In,Ou,Sc):
    if Sc != 0:
        # initiating required qubits
        X = QuantumRegister(In, 'input') 
        Y= QuantumRegister(Ou, 'output') 
        S = QuantumRegister(Sc, 'scratch')  
        
        # creating circuit with above qubits
        Circ = QuantumCircuit(X,Y,S)
        Result = QuantumCircuit(X,Y,S)
    else:
        
        # initiating required qubits
        X = QuantumRegister(In, 'input') 
        Y= QuantumRegister(Ou, 'output') 
        
        # creating circuit with above qubits
        Circ = QuantumCircuit(X,Y)
        Result = QuantumCircuit(X,Y)
    
    ##### Create you circuit below #########
    
    ### The next sloution needs much memory 
    ### + can't get solution for outbut bit number 3 becuase it will take much time & memory
    # Solution for Bit 1
#     i = 0
#     while(i<15):
#         j = i + 1
#         while(j < 15):
#             Circ.ccx(X[i],X[j],Y[1])
#             j+=1
#         i+=1

#     # Solution for bit 2 (it needs optimizetion in memory :( )
#     i = 0
#     while(i<15):
#         j = i + 1
#         while(j < 15):
#             k = j + 1
#             while(k < 15):
#                 l = k + 1
#                 while(l < 15):
#                     Circ.mct([X[i],X[j],X[k],X[l]],Y[2])
#                     break
#                     l+=1
#                 k+=1
#             j+=1
#         i+=1

#     # Solution for bit 3
#     # 8 nested loops !! (infinity :( bad solution)

#     # Solution for bit 0
#     i = 0
#     while(i<14):
#         Circ.cx(X[i],X[i+1])
#         i+=1
#     Circ.cx(X[14],Y[0])

    
    ### this solution needs too much qubits 41 while the available is 28 only ###
#     i = 0
#     j = 0
#     k = 7
#     while(i<15):
#         Circ.cx(X[i],S[j])
#         Circ.cx(X[i+1],S[j])
#         Circ.cx(X[i+2],S[j])
#         Circ.ccx(X[i],X[i+1],S[k])
#         Circ.ccx(X[i],X[i+2],S[k])
#         Circ.ccx(X[i+1],X[i+2],S[k])

#         i+=3
#         j+=1
#         k+=1

#     i = 0
#     counter = 0
#     while(counter < 2):
#         Circ.cx(S[i],S[j])
#         Circ.cx(S[i+1],S[j])
#         Circ.cx(S[i+2],S[j])
#         Circ.ccx(S[i],S[i+1],S[k])
#         Circ.ccx(S[i],S[i+2],S[k])
#         Circ.ccx(S[i+1],S[i+2],S[k])

#         i+=3
#         j+=1
#         k+=1
#         counter+=1

#     i= j
#     j = k
#     k = 17
#     counter = 0
#     while(counter < 3):
#         Circ.cx(S[i],S[j])
#         Circ.cx(S[i+1],S[j])
#         Circ.cx(S[i+2],S[j])
#         Circ.ccx(S[i],S[i+1],S[k])
#         Circ.ccx(S[i],S[i+2],S[k])
#         Circ.ccx(S[i+1],S[i+2],S[k])

#         i+=3
#         j+=1
#         k+=1
#         counter+=1

#     i = j
#     j = k
#     k = k + 1
#     Circ.cx(S[i],S[j])
#     Circ.cx(S[i+1],S[j])
#     Circ.cx(S[i+2],S[j])
#     Circ.ccx(S[i],S[i+1],S[k])
#     Circ.ccx(S[i],S[i+2],S[k])
#     Circ.ccx(S[i+1],S[i+2],S[k])
        
#     Result.cx(S[6],Y[0])
#     Result.cx(S[16],Y[1])
#     Result.cx(S[20],Y[2])
#     Result.cx(S[21],Y[3])
    
#     Circ = Circ + Result + Circ.inverse()
    
    ########################################
    
    # Uncomment to draw quantum circuit
    display(Circ.draw('mpl'))
    
    # Transpiling the circuit into u, cnot
    Circ = transpile(Circ, basis_gates=['u3','cx'])
    
    # Uncomment to draw transpiled circuit
    display(Circ.draw('mpl'))
    
    return Circ

qc_2a = Circuit_15(x15,y15,s15)

# %% [markdown]
# ### Grader

# %%
from qc_grader import grade_ex2a

grade_ex2a(qc_2a)
# Out:
# Checking your circuit...
# Traceback (most recent call last):
#   File "<ipython-input-2-c37e10a2920a>", line 3, in <module>
#     grade_ex2a(qc_2a)
#   File "/opt/conda/lib/python3.8/site-packages/qc_grader/exercises/qc/exercise2.py", line 11, in grade_ex2a
#     ok, msg = precheck_exercise(circuit, 2, 1)
#   File "/opt/conda/lib/python3.8/site-packages/qc_grader/exercises/qc/utils.py", line 132, in precheck_exercise
#     is_correct = verify_circuit(qc, test_inputs, expected_outputs)
#   File "/opt/conda/lib/python3.8/site-packages/qc_grader/exercises/qc/utils.py", line 110, in verify_circuit
#     results = execute(test_qc, qasmsim).result().get_counts()
#   File "/opt/conda/lib/python3.8/site-packages/qiskit/result/result.py", line 259, in get_counts
#     exp = self._get_experiment(key)
#   File "/opt/conda/lib/python3.8/site-packages/qiskit/result/result.py", line 380, in _get_experiment
#     raise QiskitError(result_status, ", ", exp_status)
# QiskitError: 'ERROR:  [Experiment 0] QasmSimulator: Insufficient memory for 41-qubit circuit using "statevector" method. You could try using the "matrix_product_state" or "extended_stabilizer" method instead. ,  ERROR: QasmSimulator: Insufficient memory for 41-qubit circuit using "statevector" method. You could try using the "matrix_product_state" or "extended_stabilizer" method instead.'
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=QiskitError: ERROR:  [Experiment 0] QasmSimulator: Insufficient memory for 41-qubit circuit using "statevector" method. You could try using the "matrix_product_state" or "extended_stabilizer" method instead. ,  ERROR: QasmSimulator: Insufficient memory for 41-qubit circuit using "statevector" method. You could try using the "matrix_product_state" or "extended_stabilizer" method instead." target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %% [markdown]
# ## b) Circuit for n = 16 Popcount function

# %%
# Importing the qiskit module
from qiskit import *

# Defining input, output and scratch qubits
x16 =    # number of input qubits
y16 =    # number of output qubit 
s16 =    # number of scratch qubit

# Defining Quantum Circuit with the given circuits
def Circuit_16(In,Ou,Sc):
    if Sc != 0:
        # initiating required qubits
        X = QuantumRegister(In, 'input') 
        Y= QuantumRegister(Ou, 'output') 
        S = QuantumRegister(Sc, 'scratch')  
        
        # creating circuit with above qubits
        Circ = QuantumCircuit(X,Y,S)
    else:
        
        # initiating required qubits
        X = QuantumRegister(In, 'input') 
        Y= QuantumRegister(Ou, 'output') 
        
        # creating circuit with above qubits
        Circ = QuantumCircuit(X,Y)
    
    ##### Create you circuit below #########
    
    
    
    ########################################
    
    # Uncomment to draw quantum circuit
#     display(Circ.draw('mpl'))
    
    # Transpiling the circuit into u, cnot
    Circ = transpile(Circ, basis_gates=['u3','cx'])
    
    # Uncomment to draw transpiled circuit
#     display(Circ.draw('mpl'))
    
    return Circ

qc_2b = Circuit_16(x16,y16,s16)

# %% [markdown]
# ### Grader

# %%
from qc_grader import grade_ex2b

grade_ex2b(qc_2b)

# %% [markdown]
# # Circuit verification and Cost Metric
#
# $\textbf{Costing metric:}$ Circuit implementation cost is computed as follows,
# $$\text{Cost} = G+D+\frac{nS}{2},$$
# where $G$ is the number of $\text{CNOT}$ gates used (note how the single-qubit gates are "free", which takes into account their relatively small implementation cost), $D$ is the two-qubit circuit depth (defined as the maximum length of the shortest path from any starting qubit to any ending qubit in the circuit going left, up, or down along the lines in the circuit diagram and counting the number of two-qubit gates), and $S$ is the number of scratch qubits used.  The timeout for verification is set to $5$ minutes.  All implementations that time out or compute any of the popcount outputs incorrectly are assigned the score of ${+}\infty$; the implementation with the smallest value of $\text{Cost}$ wins.

# %% [markdown]
# ### Submission for evaluation

# %%
## Uncomment and run the following code to submit

# from qc_grader import submit_ex2a, submit_ex2b

# submit_ex2a(qc_2a)  #To submit exercise 2a

# submit_ex2b(qc_2b)  #To submit exercise 2b
